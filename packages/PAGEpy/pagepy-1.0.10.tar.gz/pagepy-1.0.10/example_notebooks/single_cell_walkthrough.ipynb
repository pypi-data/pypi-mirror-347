# %%
from PAGEpy import PAGEpy_plot
from PAGEpy import pso
from PAGEpy.format_data_class import FormatData
from PAGEpy.pred_ann_model import PredAnnModel
import pickle
import pandas as pd
from PAGEpy import PAGEpy_utils

#memory growth is enabled for for the gpu
PAGEpy_utils.init_cuda()

# HVGs are selected by default, as opposed to the differential expression 
current_data = FormatData(data_dir = '/your/dir/with_single_cell_data_dir/', gene_selection = 'HVG', pval_correction = 'benjamini-hochberg', hvg_count = 2000)

# the selected genes can be loaded from the local directory, however, they are also an attribte of the FormatData object
genes_path = '/your/dir/feature_set.pkl'

with open(genes_path, 'rb') as f:
    current_genes = pickle.load(f)

# train the model
old_model = PredAnnModel(current_data,current_genes,num_epochs=500,auc_threshold=1)

# evaluate the model
PAGEpy_plot.evaluate_model(old_model, current_data)
# Out:
# 2025-03-30 09:59:09.947799: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Memory growth enabled for PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Anndata successfully constructed.
# Anndata object counts are now normalized.
# The total length of the genes list or feature set is: 2000.
# Epoch 0, Avg Outcome Loss: 0.6976, Train AUC: 0.4981, Train Accuracy: 0.4518, Test AUC: 0.4952, Test Accuracy: 0.4520
# Epoch 10, Avg Outcome Loss: 0.5652, Train AUC: 0.8830, Train Accuracy: 0.8118, Test AUC: 0.8669, Test Accuracy: 0.8025
# Epoch 20, Avg Outcome Loss: 0.4283, Train AUC: 0.9166, Train Accuracy: 0.8382, Test AUC: 0.8955, Test Accuracy: 0.8386
# Epoch 30, Avg Outcome Loss: 0.3548, Train AUC: 0.9416, Train Accuracy: 0.8688, Test AUC: 0.9115, Test Accuracy: 0.8443
# Epoch 40, Avg Outcome Loss: 0.2897, Train AUC: 0.9569, Train Accuracy: 0.8883, Test AUC: 0.9188, Test Accuracy: 0.8528
# Epoch 50, Avg Outcome Loss: 0.2494, Train AUC: 0.9723, Train Accuracy: 0.9147, Test AUC: 0.9252, Test Accuracy: 0.8585
# Epoch 60, Avg Outcome Loss: 0.1913, Train AUC: 0.9847, Train Accuracy: 0.9301, Test AUC: 0.9251, Test Accuracy: 0.8386
# Epoch 70, Avg Outcome Loss: 0.1316, Train AUC: 0.9919, Train Accuracy: 0.9510, Test AUC: 0.9213, Test Accuracy: 0.8557
# Epoch 80, Avg Outcome Loss: 0.0937, Train AUC: 0.9964, Train Accuracy: 0.9710, Test AUC: 0.9184, Test Accuracy: 0.8376
# Epoch 90, Avg Outcome Loss: 0.0507, Train AUC: 0.9986, Train Accuracy: 0.9834, Test AUC: 0.9155, Test Accuracy: 0.8386
# Epoch 100, Avg Outcome Loss: 0.0392, Train AUC: 0.9995, Train Accuracy: 0.9888, Test AUC: 0.9118, Test Accuracy: 0.8452
# Epoch 110, Avg Outcome Loss: 0.0288, Train AUC: 0.9999, Train Accuracy: 0.9931, Test AUC: 0.9106, Test Accuracy: 0.8462
# Epoch 120, Avg Outcome Loss: 0.0193, Train AUC: 0.9999, Train Accuracy: 0.9948, Test AUC: 0.9095, Test Accuracy: 0.8414
# Epoch 130, Avg Outcome Loss: 0.0128, Train AUC: 1.0000, Train Accuracy: 0.9952, Test AUC: 0.9081, Test Accuracy: 0.8424
# Epoch 140, Avg Outcome Loss: 0.0084, Train AUC: 1.0000, Train Accuracy: 0.9960, Test AUC: 0.9088, Test Accuracy: 0.8452
# Epoch 150, Avg Outcome Loss: 0.0108, Train AUC: 1.0000, Train Accuracy: 0.9962, Test AUC: 0.9079, Test Accuracy: 0.8424
# Epoch 160, Avg Outcome Loss: 0.0085, Train AUC: 1.0000, Train Accuracy: 0.9964, Test AUC: 0.9078, Test Accuracy: 0.8471
# Epoch 170, Avg Outcome Loss: 0.0030, Train AUC: 1.0000, Train Accuracy: 0.9967, Test AUC: 0.9066, Test Accuracy: 0.8443
# Epoch 180, Avg Outcome Loss: 0.0047, Train AUC: 1.0000, Train Accuracy: 0.9969, Test AUC: 0.9054, Test Accuracy: 0.8405
# Epoch 190, Avg Outcome Loss: 0.0052, Train AUC: 1.0000, Train Accuracy: 0.9971, Test AUC: 0.9052, Test Accuracy: 0.8443
# Epoch 200, Avg Outcome Loss: 0.0064, Train AUC: 1.0000, Train Accuracy: 0.9981, Test AUC: 0.9049, Test Accuracy: 0.8433
# Epoch 210, Avg Outcome Loss: 0.0043, Train AUC: 1.0000, Train Accuracy: 0.9981, Test AUC: 0.9041, Test Accuracy: 0.8424
# Epoch 220, Avg Outcome Loss: 0.0041, Train AUC: 1.0000, Train Accuracy: 0.9988, Test AUC: 0.9019, Test Accuracy: 0.8386
# Epoch 230, Avg Outcome Loss: 0.0056, Train AUC: 1.0000, Train Accuracy: 0.9990, Test AUC: 0.9036, Test Accuracy: 0.8452
# Epoch 240, Avg Outcome Loss: 0.0013, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.9013, Test Accuracy: 0.8424
# Epoch 250, Avg Outcome Loss: 0.0030, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8989, Test Accuracy: 0.8338
# Epoch 260, Avg Outcome Loss: 0.0013, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.9013, Test Accuracy: 0.8433
# Epoch 270, Avg Outcome Loss: 0.0026, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.9003, Test Accuracy: 0.8395
# Epoch 280, Avg Outcome Loss: 0.0015, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8991, Test Accuracy: 0.8376
# Epoch 290, Avg Outcome Loss: 0.0010, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8963, Test Accuracy: 0.8376
# Epoch 300, Avg Outcome Loss: 0.0008, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8992, Test Accuracy: 0.8424
# Epoch 310, Avg Outcome Loss: 0.0007, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8950, Test Accuracy: 0.8338
# Epoch 320, Avg Outcome Loss: 0.0005, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8952, Test Accuracy: 0.8367
# Epoch 330, Avg Outcome Loss: 0.0006, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8941, Test Accuracy: 0.8395
# Epoch 340, Avg Outcome Loss: 0.0016, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8954, Test Accuracy: 0.8367
# Epoch 350, Avg Outcome Loss: 0.0012, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8940, Test Accuracy: 0.8395
# Epoch 360, Avg Outcome Loss: 0.0002, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8943, Test Accuracy: 0.8386
# Epoch 370, Avg Outcome Loss: 0.0004, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8928, Test Accuracy: 0.8376
# Epoch 380, Avg Outcome Loss: 0.0030, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8897, Test Accuracy: 0.8405
# Epoch 390, Avg Outcome Loss: 0.0024, Train AUC: 1.0000, Train Accuracy: 0.9993, Test AUC: 0.8921, Test Accuracy: 0.8300
# Epoch 400, Avg Outcome Loss: 0.0003, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8892, Test Accuracy: 0.8424
# Epoch 410, Avg Outcome Loss: 0.0021, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8912, Test Accuracy: 0.8300
# Epoch 420, Avg Outcome Loss: 0.0003, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8880, Test Accuracy: 0.8367
# Epoch 430, Avg Outcome Loss: 0.0010, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8910, Test Accuracy: 0.8357
# Epoch 440, Avg Outcome Loss: 0.0012, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8885, Test Accuracy: 0.8395
# Epoch 450, Avg Outcome Loss: 0.0003, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8895, Test Accuracy: 0.8376
# Epoch 460, Avg Outcome Loss: 0.0003, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8875, Test Accuracy: 0.8367
# Epoch 470, Avg Outcome Loss: 0.0002, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8864, Test Accuracy: 0.8386
# Epoch 480, Avg Outcome Loss: 0.0007, Train AUC: 1.0000, Train Accuracy: 0.9995, Test AUC: 0.8892, Test Accuracy: 0.8262
# Epoch 490, Avg Outcome Loss: 0.0027, Train AUC: 1.0000, Train Accuracy: 0.9998, Test AUC: 0.8877, Test Accuracy: 0.8386
# max train accuracy: 1.0
# max train auc: 1.0
# max test accuracy: 0.87
# max test auc: 0.93

# %%
# the pso algorithm can be use to optimze the solution
best_solution, best_fitness = pso.binary_pso(current_genes, current_data, 200, 15,  C1 = 2, C2 = 1.5)
# Out:
# Current mixed precision policy: <Policy "mixed_float16">
# Total time for generation 1: 11042.28 seconds
# Generation 1: Best AUC = 0.944, Avg = 0.93908
#
#
# Total time for generation 2: 11188.35 seconds
# Generation 2: Best AUC = 0.944, Avg = 0.938
#
#
# Total time for generation 3: 11202.86 seconds
# Generation 3: Best AUC = 0.946, Avg = 0.94

# %%
# the results of pso optimizatoin can be monitored
pso_df = pd.read_pickle("pso_df.pkl")
pso_dict = pd.read_pickle("pso_dict.pkl")

PAGEpy_plot.plot_pso_row_averages(pso_df)
PAGEpy_plot.plot_hamming_distance(pso_dict)
PAGEpy_plot.plot_sorted_frequencies(pso_dict, pso_df)

# %%
# the optimised solution is saved locally, however, the returned varible from the binary_pso function can also be passed to the model (see below)                                             
# pso_genes = [item for item, m in zip(current_genes, best_solution) if m == 1]

# othervise just load the locally stored result file

# Load the saved genes list
with open('pso_genes_result.pkl', 'rb') as f:
    pso_genes = pickle.load(f)

# %%
# now use this gene list to train a new model, which you can then evaluate
new_model = PredAnnModel(current_data,pso_genes,num_epochs=500)
PAGEpy_plot.evaluate_model(new_model, current_data)
