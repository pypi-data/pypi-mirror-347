# %%
import json
from floods_html import floods_html

JSON_FILE = "/ec/res4/scratch/ecm7348/danu-ci/results/integration/efas/20240901/web_products/points/DE000137_2024090100.json"
SVG_PREFIX = "https://european-flood.emergency.copernicus.eu/mapserver/images/forecasts/2024/202409/2024090100/points/"

with open(JSON_FILE) as f:
    json_info = json.load(f)

htmls = floods_html.json_to_html(json_info['data'], svg_location=SVG_PREFIX)

# %%
from IPython.display import display, HTML

for html in htmls:
    display(HTML(html))
# Out:
#         <span>
#             <h4>Discharge Hydrograph None</h4>
#             <img src=https://european-flood.emergency.copernicus.eu/mapserver/images/forecasts/2024/202409/2024090100/points/DE000137_DisCombined_PGEN2024090100.svg width=800 height=300 />
#         </span>
#         <span>
#             <h4>Discharge Hydrograph (ECMWF-ENS)</h4>
#             <img src=https://european-flood.emergency.copernicus.eu/mapserver/images/forecasts/2024/202409/2024090100/points/DE000137_Dis_EUE2024090100.svg width=800 height=300 />
#         </span>
#         <span>
#             <h4>Upstream Rainfall (ECMWF-ENS)</h4>
#             <img src=https://european-flood.emergency.copernicus.eu/mapserver/images/forecasts/2024/202409/2024090100/points/DE000137_Rups_EUE2024090100.svg width=800 height=300 />
#         </span>
#         <span>
#             <h4>Upstream Snowmelt (ECMWF-ENS)</h4>
# ...
